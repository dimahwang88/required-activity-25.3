# %% [markdown]
# ## Firstly, all necessary packages must be installed
#
# - numpy
# - pandas
# - tqdm
# - scikit-image
# - tensorflow
# - keras (high-level deep learning library)

# %%
# !conda install --yes -c anaconda numpy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/dmitriy.khvan/anaconda3/envs/conda_new
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           5 KB  anaconda
#     certifi-2022.6.15          |   py37hecd8cb5_0         157 KB  anaconda
#     intel-openmp-2021.4.0      |    hecd8cb5_3538         1.2 MB  anaconda
#     mkl-2021.4.0               |     hecd8cb5_637       209.2 MB  anaconda
#     mkl-service-2.4.0          |   py37h9ed2024_0          47 KB  anaconda
#     mkl_fft-1.3.1              |   py37h4ab4a9b_0         182 KB  anaconda
#     mkl_random-1.2.2           |   py37hb2f4e1b_0         296 KB  anaconda
#     numpy-1.21.5               |   py37h2e5f0a9_3          10 KB  anaconda
#     numpy-base-1.21.5          |   py37h3b1a694_3         6.0 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:       217.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               anaconda/osx-64::blas-1.0-mkl None
#   intel-openmp       anaconda/osx-64::intel-openmp-2021.4.0-hecd8cb5_3538 None
#   mkl                anaconda/osx-64::mkl-2021.4.0-hecd8cb5_637 None
#   mkl-service        anaconda/osx-64::mkl-service-2.4.0-py37h9ed2024_0 None
#   mkl_fft            anaconda/osx-64::mkl_fft-1.3.1-py37h4ab4a9b_0 None
#   mkl_random         anaconda/osx-64::mkl_random-1.2.2-py37hb2f4e1b_0 None
#   numpy              anaconda/osx-64::numpy-1.21.5-py37h2e5f0a9_3 None
#   numpy-base         anaconda/osx-64::numpy-base-1.21.5-py37h3b1a694_3 None
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.10.11~ --> anaconda::ca-certificates-2022.4.26-hecd8cb5_0 None
#   certifi            pkgs/main::certifi-2022.9.24-py37hecd~ --> anaconda::certifi-2022.6.15-py37hecd8cb5_0 None
#
#
#
# Downloading and Extracting Packages
# intel-openmp-2021.4. | 1.2 MB    | ##################################### | 100%
# certifi-2022.6.15    | 157 KB    | ##################################### | 100%
# blas-1.0             | 5 KB      | ##################################### | 100%
# mkl_fft-1.3.1        | 182 KB    | ##################################### | 100%
# mkl-service-2.4.0    | 47 KB     | ##################################### | 100%
# mkl-2021.4.0         | 209.2 MB  | ##################################### | 100%
# numpy-1.21.5         | 10 KB     | ##################################### | 100%
# mkl_random-1.2.2     | 296 KB    | ##################################### | 100%
# numpy-base-1.21.5    | 6.0 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done

# %%
# !conda install --yes -c anaconda pandas
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done

# %%
conda install --yes -c conda-forge matplotlib
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/dmitriy.khvan/anaconda3/envs/conda_new
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.0.9               |       hb7f2c08_8          19 KB  conda-forge
#     brotli-bin-1.0.9           |       hb7f2c08_8          17 KB  conda-forge
#     cycler-0.11.0              |     pyhd8ed1ab_0          10 KB  conda-forge
#     freetype-2.10.4            |       h4cff582_1         890 KB  conda-forge
#     giflib-5.2.1               |       hbcb3906_2          71 KB  conda-forge
#     jpeg-9e                    |       hac89ed1_2         260 KB  conda-forge
#     kiwisolver-1.4.4           |   py37h229a17a_0          63 KB  conda-forge
#     lcms2-2.14                 |       h90f4b2a_0         248 KB  conda-forge
#     lerc-3.0                   |       he49afe7_0         170 KB  conda-forge
#     libbrotlicommon-1.0.9      |       hb7f2c08_8          64 KB  conda-forge
#     libbrotlidec-1.0.9         |       hb7f2c08_8          33 KB  conda-forge
#     libbrotlienc-1.0.9         |       hb7f2c08_8         303 KB  conda-forge
#     libwebp-1.2.4              |       hfa4350a_0          84 KB  conda-forge
#     libwebp-base-1.2.4         |       h775f41a_0         385 KB  conda-forge
#     lz4-c-1.9.3                |       he49afe7_1         155 KB  conda-forge
#     matplotlib-3.5.3           |   py37hf985489_2           7 KB  conda-forge
#     matplotlib-base-3.5.3      |   py37hb4e9e99_0         7.4 MB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     pillow-9.2.0               |   py37hde71d04_1         623 KB
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        10.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             conda-forge/osx-64::brotli-1.0.9-hb7f2c08_8 None
#   brotli-bin         conda-forge/osx-64::brotli-bin-1.0.9-hb7f2c08_8 None
#   cycler             conda-forge/noarch::cycler-0.11.0-pyhd8ed1ab_0 None
#   fonttools          pkgs/main/noarch::fonttools-4.25.0-pyhd3eb1b0_0 None
#   freetype           conda-forge/osx-64::freetype-2.10.4-h4cff582_1 None
#   giflib             conda-forge/osx-64::giflib-5.2.1-hbcb3906_2 None
#   jpeg               conda-forge/osx-64::jpeg-9e-hac89ed1_2 None
#   kiwisolver         conda-forge/osx-64::kiwisolver-1.4.4-py37h229a17a_0 None
#   lcms2              conda-forge/osx-64::lcms2-2.14-h90f4b2a_0 None
#   lerc               conda-forge/osx-64::lerc-3.0-he49afe7_0 None
#   libbrotlicommon    conda-forge/osx-64::libbrotlicommon-1.0.9-hb7f2c08_8 None
#   libbrotlidec       conda-forge/osx-64::libbrotlidec-1.0.9-hb7f2c08_8 None
#   libbrotlienc       conda-forge/osx-64::libbrotlienc-1.0.9-hb7f2c08_8 None
#   libdeflate         pkgs/main/osx-64::libdeflate-1.8-h9ed2024_5 None
#   libpng             pkgs/main/osx-64::libpng-1.6.37-ha441bb4_0 None
#   libtiff            pkgs/main/osx-64::libtiff-4.4.0-h2cd0358_2 None
#   libwebp            conda-forge/osx-64::libwebp-1.2.4-hfa4350a_0 None
#   libwebp-base       conda-forge/osx-64::libwebp-base-1.2.4-h775f41a_0 None
#   lz4-c              conda-forge/osx-64::lz4-c-1.9.3-he49afe7_1 None
#   matplotlib         conda-forge/osx-64::matplotlib-3.5.3-py37hf985489_2 None
#   matplotlib-base    conda-forge/osx-64::matplotlib-base-3.5.3-py37hb4e9e99_0 None
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0 None
#   pillow             pkgs/main/osx-64::pillow-9.2.0-py37hde71d04_1 None
#   python_abi         conda-forge/osx-64::python_abi-3.7-2_cp37m None
#   zstd               pkgs/main/osx-64::zstd-1.5.2-hcb37349_0 None
#
# The following packages will be UPDATED:
#
#   ca-certificates    anaconda::ca-certificates-2022.4.26-h~ --> conda-forge::ca-certificates-2022.9.24-h033912b_0 None
#   certifi            anaconda/osx-64::certifi-2022.6.15-py~ --> conda-forge/noarch::certifi-2022.9.24-pyhd8ed1ab_0 None
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   openssl              pkgs/main::openssl-1.1.1s-hca72f7f_0 --> conda-forge::openssl-1.1.1s-hfd90126_0 None
#
#
#
# Downloading and Extracting Packages
# libwebp-1.2.4        | 84 KB     | ##################################### | 100%
# jpeg-9e              | 260 KB    | ##################################### | 100%
# libbrotlidec-1.0.9   | 33 KB     | ##################################### | 100%
# lerc-3.0             | 170 KB    | ##################################### | 100%
# freetype-2.10.4      | 890 KB    | ##################################### | 100%
# lz4-c-1.9.3          | 155 KB    | ##################################### | 100%
# matplotlib-3.5.3     | 7 KB      | ##################################### | 100%
# munkres-1.1.4        | 12 KB     | ##################################### | 100%
# python_abi-3.7       | 4 KB      | ##################################### | 100%
# brotli-1.0.9         | 19 KB     | ##################################### | 100%
# giflib-5.2.1         | 71 KB     | ##################################### | 100%
# libwebp-base-1.2.4   | 385 KB    | ##################################### | 100%
# cycler-0.11.0        | 10 KB     | ##################################### | 100%
# libbrotlicommon-1.0. | 64 KB     | ##################################### | 100%
# lcms2-2.14           | 248 KB    | ##################################### | 100%
# pillow-9.2.0         | 623 KB    | ##################################### | 100%
# kiwisolver-1.4.4     | 63 KB     | ##################################### | 100%
# libbrotlienc-1.0.9   | 303 KB    | ##################################### | 100%
# matplotlib-base-3.5. | 7.4 MB    | ##################################### | 100%
# brotli-bin-1.0.9     | 17 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !conda install --yes -c conda-forge tqdm
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/dmitriy.khvan/anaconda3/envs/conda_new
#
#   added / updated specs:
#     - tqdm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     colorama-0.4.6             |     pyhd8ed1ab_0          25 KB  conda-forge
#     tqdm-4.64.1                |     pyhd8ed1ab_0          82 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         106 KB
#
# The following NEW packages will be INSTALLED:
#
#   colorama           conda-forge/noarch::colorama-0.4.6-pyhd8ed1ab_0 None
#   tqdm               conda-forge/noarch::tqdm-4.64.1-pyhd8ed1ab_0 None
#
#
#
# Downloading and Extracting Packages
# colorama-0.4.6       | 25 KB     | ##################################### | 100%
# tqdm-4.64.1          | 82 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done

# %%
# !conda install --yes -c anaconda scikit-image
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/dmitriy.khvan/anaconda3/envs/conda_new
#
#   added / updated specs:
#     - scikit-image
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cloudpickle-2.0.0          |     pyhd3eb1b0_0          31 KB  anaconda
#     cytoolz-0.11.0             |   py37haf1e3a3_0         334 KB  anaconda
#     dask-core-2021.10.0        |     pyhd3eb1b0_0         772 KB  anaconda
#     fsspec-2022.3.0            |   py37hecd8cb5_0         192 KB  anaconda
#     imageio-2.9.0              |     pyhd3eb1b0_0         3.1 MB  anaconda
#     libgfortran-3.0.1          |       h93005f0_2         495 KB  anaconda
#     llvm-openmp-12.0.0         |       h0dcd299_1         300 KB  anaconda
#     locket-1.0.0               |   py37hecd8cb5_0          12 KB  anaconda
#     networkx-2.6.3             |     pyhd3eb1b0_0         1.5 MB  anaconda
#     partd-1.2.0                |     pyhd3eb1b0_1          18 KB  anaconda
#     pywavelets-1.3.0           |   py37hca72f7f_0         4.3 MB  anaconda
#     pyyaml-6.0                 |   py37hca72f7f_1         163 KB  anaconda
#     scikit-image-0.19.2        |   py37hae1ba45_0        11.0 MB  anaconda
#     scipy-1.7.3                |   py37h8c7af03_0        20.0 MB  anaconda
#     tifffile-2020.10.1         |   py37h0cf3a3e_2         263 KB  anaconda
#     toolz-0.11.2               |     pyhd3eb1b0_0          48 KB  anaconda
#     yaml-0.2.5                 |       haf1e3a3_0          85 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:        42.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   cloudpickle        anaconda/noarch::cloudpickle-2.0.0-pyhd3eb1b0_0 None
#   cytoolz            anaconda/osx-64::cytoolz-0.11.0-py37haf1e3a3_0 None
#   dask-core          anaconda/noarch::dask-core-2021.10.0-pyhd3eb1b0_0 None
#   fsspec             anaconda/osx-64::fsspec-2022.3.0-py37hecd8cb5_0 None
#   imageio            anaconda/noarch::imageio-2.9.0-pyhd3eb1b0_0 None
#   libgfortran        anaconda/osx-64::libgfortran-3.0.1-h93005f0_2 None
#   llvm-openmp        anaconda/osx-64::llvm-openmp-12.0.0-h0dcd299_1 None
#   locket             anaconda/osx-64::locket-1.0.0-py37hecd8cb5_0 None
#   networkx           anaconda/noarch::networkx-2.6.3-pyhd3eb1b0_0 None
#   partd              anaconda/noarch::partd-1.2.0-pyhd3eb1b0_1 None
#   pywavelets         anaconda/osx-64::pywavelets-1.3.0-py37hca72f7f_0 None
#   pyyaml             anaconda/osx-64::pyyaml-6.0-py37hca72f7f_1 None
#   scikit-image       anaconda/osx-64::scikit-image-0.19.2-py37hae1ba45_0 None
#   scipy              anaconda/osx-64::scipy-1.7.3-py37h8c7af03_0 None
#   tifffile           anaconda/osx-64::tifffile-2020.10.1-py37h0cf3a3e_2 None
#   toolz              anaconda/noarch::toolz-0.11.2-pyhd3eb1b0_0 None
#   yaml               anaconda/osx-64::yaml-0.2.5-haf1e3a3_0 None
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2022.9.2~ --> anaconda::ca-certificates-2022.4.26-hecd8cb5_0 None
#   certifi            conda-forge/noarch::certifi-2022.9.24~ --> anaconda/osx-64::certifi-2022.6.15-py37hecd8cb5_0 None
#   openssl            conda-forge::openssl-1.1.1s-hfd90126_0 --> pkgs/main::openssl-1.1.1s-hca72f7f_0 None
#
#
#
# Downloading and Extracting Packages
# imageio-2.9.0        | 3.1 MB    | ##################################### | 100%
# scipy-1.7.3          | 20.0 MB   | ##################################### | 100%
# networkx-2.6.3       | 1.5 MB    | ##################################### | 100%
# partd-1.2.0          | 18 KB     | ##################################### | 100%
# tifffile-2020.10.1   | 263 KB    | ##################################### | 100%
# yaml-0.2.5           | 85 KB     | ##################################### | 100%
# pyyaml-6.0           | 163 KB    | ##################################### | 100%
# toolz-0.11.2         | 48 KB     | ##################################### | 100%
# libgfortran-3.0.1    | 495 KB    | ##################################### | 100%
# fsspec-2022.3.0      | 192 KB    | ##################################### | 100%
# dask-core-2021.10.0  | 772 KB    | ##################################### | 100%
# cytoolz-0.11.0       | 334 KB    | ##################################### | 100%
# locket-1.0.0         | 12 KB     | ##################################### | 100%
# pywavelets-1.3.0     | 4.3 MB    | ##################################### | 100%
# cloudpickle-2.0.0    | 31 KB     | ##################################### | 100%
# llvm-openmp-12.0.0   | 300 KB    | ##################################### | 100%
# scikit-image-0.19.2  | 11.0 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.11.0-cp37-cp37m-macosx_10_14_x86_64.whl (244.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 MB 7.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.20 in /Users/dmitriy.khvan/anaconda3/envs/conda_new/lib/python3.7/site-packages (from tensorflow) (1.21.5)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.14.1-cp37-cp37m-macosx_10_9_x86_64.whl (34 kB)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting libclang>=13.0.0
#   Using cached libclang-14.0.6-py2.py3-none-macosx_10_9_x86_64.whl (13.2 MB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.50.0-cp37-cp37m-macosx_10_10_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 30.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /Users/dmitriy.khvan/anaconda3/envs/conda_new/lib/python3.7/site-packages (from tensorflow) (65.5.0)
# Collecting keras<2.12,>=2.11.0
#   Using cached keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.1.1-py3-none-any.whl (6.2 kB)
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-22.11.23-py2.py3-none-any.whl (26 kB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 kB 11.1 MB/s eta 0:00:0000:01
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.28.0-cp37-cp37m-macosx_10_14_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 15.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging in /Users/dmitriy.khvan/anaconda3/envs/conda_new/lib/python3.7/site-packages (from tensorflow) (21.3)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: six>=1.12.0 in /Users/dmitriy.khvan/anaconda3/envs/conda_new/lib/python3.7/site-packages (from tensorflow) (1.16.0)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 kB 3.7 MB/s eta 0:00:00
# Collecting h5py>=2.9.0
#   Downloading h5py-3.7.0-cp37-cp37m-macosx_10_9_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 28.2 MB/s eta 0:00:0000:0100:01
# Collecting tensorboard<2.12,>=2.11
#   Downloading tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 28.4 MB/s eta 0:00:0000:0100:01
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp37-cp37m-macosx_10_9_x86_64.whl (979 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 979.7/979.7 kB 17.5 MB/s eta 0:00:0000:01
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/dmitriy.khvan/anaconda3/envs/conda_new/lib/python3.7/site-packages (from tensorflow) (4.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/dmitriy.khvan/anaconda3/envs/conda_new/lib/python3.7/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 17.8 MB/s eta 0:00:0000:01
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 kB 6.8 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 22.5 MB/s eta 0:00:0000:0100:01
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 1.7 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 2.6 MB/s eta 0:00:00
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.14.1-py2.py3-none-any.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/dmitriy.khvan/anaconda3/envs/conda_new/lib/python3.7/site-packages (from packaging->tensorflow) (3.0.9)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/dmitriy.khvan/anaconda3/envs/conda_new/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (4.11.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dmitriy.khvan/anaconda3/envs/conda_new/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.4)
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dmitriy.khvan/anaconda3/envs/conda_new/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.6.15)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/dmitriy.khvan/anaconda3/envs/conda_new/lib/python3.7/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/dmitriy.khvan/anaconda3/envs/conda_new/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (3.8.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 3.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: tensorboard-plugin-wit, pyasn1, libclang, flatbuffers, wrapt, werkzeug, urllib3, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, pyasn1-modules, protobuf, opt-einsum, oauthlib, keras, h5py, grpcio, google-pasta, gast, charset-normalizer, cachetools, astunparse, absl-py, requests, markdown, google-auth, requests-oauthlib, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed absl-py-1.3.0 astunparse-1.6.3 cachetools-5.2.0 charset-normalizer-2.1.1 flatbuffers-22.11.23 gast-0.4.0 google-auth-2.14.1 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.50.0 h5py-3.7.0 keras-2.11.0 libclang-14.0.6 markdown-3.4.1 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.19.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.28.1 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.11.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-io-gcs-filesystem-0.28.0 termcolor-2.1.1 urllib3-1.26.13 werkzeug-2.2.2 wrapt-1.14.1

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /Users/dmitriy.khvan/anaconda3/envs/conda_new/lib/python3.7/site-packages (2.11.0)

# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers import Conv2D, MaxPooling2D, Input, Conv2DTranspose, Concatenate, BatchNormalization, UpSampling2D
from tensorflow.keras.layers import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

# %%
# Set some parameters
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3

# train and test data must be saved under ./data directory
TRAIN_PATH = './data/stage1_train/'
TEST_PATH = './data/stage1_test/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')

# fixed seed for reproducability
seed = 42
random.seed = seed
np.random.seed = seed

# %%
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# /Users/dmitriy.khvan/anaconda3/envs/conda_new/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   This is separate from the ipykernel package so we can avoid doing imports until
#   0%|                                                                                                                                                            | 0/670 [00:00<?, ?it/s]/Users/dmitriy.khvan/anaconda3/envs/conda_new/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # This is added back by InteractiveShellApp.init_path()
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 670/670 [04:48<00:00,  2.32it/s]
# Getting and resizing test images ...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 65/65 [00:01<00:00, 35.91it/s]
# Done!

# %%
# Visualising samples from train and test datasets
ix = random.randint(0, len(train_ids))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()

# %%
# a helper method to compute IoU - Intersection over Union.
def mean_iou(y_true, y_pred):
    yt0 = y_true[:,:,:,0]
    yp0 = K.cast(y_pred[:,:,:,0] > 0.5, 'float32')
    inter = tf.math.count_nonzero(tf.logical_and(tf.equal(yt0, 1), tf.equal(yp0, 1)))
    union = tf.math.count_nonzero(tf.add(yt0, yp0))
    iou = tf.where(tf.equal(union, 0), 1., tf.cast(inter/union, 'float32'))
    return iou

# %%
# Build the network - UNet architecture
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[mean_iou])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  lambda_3 (Lambda)              (None, 128, 128, 3)  0           ['input_4[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 128, 128, 16  448         ['lambda_3[0][0]']
#                                 )
#
#  dropout_19 (Dropout)           (None, 128, 128, 16  0           ['conv2d_40[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 128, 128, 16  2320        ['dropout_19[0][0]']
#                                 )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 64, 64, 16)  0           ['conv2d_41[0][0]']
#  )
#
#  conv2d_42 (Conv2D)             (None, 64, 64, 32)   4640        ['max_pooling2d_12[0][0]']
#
#  dropout_20 (Dropout)           (None, 64, 64, 32)   0           ['conv2d_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 64, 64, 32)   9248        ['dropout_20[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 32, 32, 32)  0           ['conv2d_43[0][0]']
#  )
#
#  conv2d_44 (Conv2D)             (None, 32, 32, 64)   18496       ['max_pooling2d_13[0][0]']
#
#  dropout_21 (Dropout)           (None, 32, 32, 64)   0           ['conv2d_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 32, 32, 64)   36928       ['dropout_21[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 16, 16, 64)  0           ['conv2d_45[0][0]']
#  )
#
#  conv2d_46 (Conv2D)             (None, 16, 16, 128)  73856       ['max_pooling2d_14[0][0]']
#
#  dropout_22 (Dropout)           (None, 16, 16, 128)  0           ['conv2d_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 16, 16, 128)  147584      ['dropout_22[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 8, 8, 128)   0           ['conv2d_47[0][0]']
#  )
#
#  conv2d_48 (Conv2D)             (None, 8, 8, 256)    295168      ['max_pooling2d_15[0][0]']
#
#  dropout_23 (Dropout)           (None, 8, 8, 256)    0           ['conv2d_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 8, 8, 256)    590080      ['dropout_23[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 16, 16, 128)  131200     ['conv2d_49[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 16, 16, 256)  0           ['conv2d_transpose_6[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 16, 16, 128)  295040      ['concatenate_5[0][0]']
#
#  dropout_24 (Dropout)           (None, 16, 16, 128)  0           ['conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 16, 16, 128)  147584      ['dropout_24[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 32, 32, 64)  32832       ['conv2d_51[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_7[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 32, 32, 64)   73792       ['concatenate_6[0][0]']
#
#  dropout_25 (Dropout)           (None, 32, 32, 64)   0           ['conv2d_52[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 32, 32, 64)   36928       ['dropout_25[0][0]']
#
#  conv2d_transpose_8 (Conv2DTran  (None, 64, 64, 32)  8224        ['conv2d_53[0][0]']
#  spose)
#
#  concatenate_7 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_8[0][0]',
#                                                                   'conv2d_43[0][0]']
#  conv2d_54 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_7[0][0]']
#
#  dropout_26 (Dropout)           (None, 64, 64, 32)   0           ['conv2d_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 64, 64, 32)   9248        ['dropout_26[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 128, 128, 16  2064       ['conv2d_55[0][0]']
#  spose)                         )
#
#  concatenate_8 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_9[0][0]',
#                                 )                                 'conv2d_41[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 128, 128, 16  4624        ['concatenate_8[0][0]']
#                                 )
#
#  dropout_27 (Dropout)           (None, 128, 128, 16  0           ['conv2d_56[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 128, 128, 16  2320        ['dropout_27[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 128, 128, 1)  17          ['conv2d_57[0][0]']
#
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Training the model for 50 epochs
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model-dsbowl2018-1.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=16, epochs=50, 
                    callbacks=[earlystopper, checkpointer])
# Out:
# Epoch 1/50
# 38/38 [==============================] - ETA: 0s - loss: 0.4755 - mean_iou: 0.3098
# Epoch 1: val_loss improved from inf to 0.28773, saving model to model-dsbowl2018-1.h5
# 38/38 [==============================] - 40s 986ms/step - loss: 0.4755 - mean_iou: 0.3098 - val_loss: 0.2877 - val_mean_iou: 0.5621
# Epoch 2/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2619 - mean_iou: 0.6178
# Epoch 2: val_loss improved from 0.28773 to 0.20828, saving model to model-dsbowl2018-1.h5
# 38/38 [==============================] - 36s 955ms/step - loss: 0.2619 - mean_iou: 0.6178 - val_loss: 0.2083 - val_mean_iou: 0.6719
# Epoch 3/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1839 - mean_iou: 0.7303
# Epoch 3: val_loss improved from 0.20828 to 0.16082, saving model to model-dsbowl2018-1.h5
# 38/38 [==============================] - 37s 968ms/step - loss: 0.1839 - mean_iou: 0.7303 - val_loss: 0.1608 - val_mean_iou: 0.7380
# Epoch 4/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1554 - mean_iou: 0.7732
# Epoch 4: val_loss improved from 0.16082 to 0.14016, saving model to model-dsbowl2018-1.h5
# 38/38 [==============================] - 37s 977ms/step - loss: 0.1554 - mean_iou: 0.7732 - val_loss: 0.1402 - val_mean_iou: 0.7672
# Epoch 5/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1448 - mean_iou: 0.7895
# Epoch 5: val_loss did not improve from 0.14016
# 38/38 [==============================] - 36s 953ms/step - loss: 0.1448 - mean_iou: 0.7895 - val_loss: 0.1421 - val_mean_iou: 0.7669
# Epoch 6/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1403 - mean_iou: 0.7990
# Epoch 6: val_loss did not improve from 0.14016
# 38/38 [==============================] - 37s 972ms/step - loss: 0.1403 - mean_iou: 0.7990 - val_loss: 0.1522 - val_mean_iou: 0.7562
# Epoch 7/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1269 - mean_iou: 0.8165
# Epoch 7: val_loss did not improve from 0.14016
# 38/38 [==============================] - 36s 952ms/step - loss: 0.1269 - mean_iou: 0.8165 - val_loss: 0.2619 - val_mean_iou: 0.7215
# Epoch 8/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1224 - mean_iou: 0.8226
# Epoch 8: val_loss improved from 0.14016 to 0.13765, saving model to model-dsbowl2018-1.h5
# 38/38 [==============================] - 37s 971ms/step - loss: 0.1224 - mean_iou: 0.8226 - val_loss: 0.1376 - val_mean_iou: 0.7745
# Epoch 9/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1196 - mean_iou: 0.8262
# Epoch 9: val_loss improved from 0.13765 to 0.11755, saving model to model-dsbowl2018-1.h5
# 38/38 [==============================] - 38s 1s/step - loss: 0.1196 - mean_iou: 0.8262 - val_loss: 0.1175 - val_mean_iou: 0.8045
# Epoch 10/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1096 - mean_iou: 0.8431
# Epoch 10: val_loss did not improve from 0.11755
# 38/38 [==============================] - 37s 974ms/step - loss: 0.1096 - mean_iou: 0.8431 - val_loss: 0.1191 - val_mean_iou: 0.8037
# Epoch 11/50
# 38/38 [==============================] - ETA: 0s - loss: 0.1073 - mean_iou: 0.8458
# Epoch 11: val_loss improved from 0.11755 to 0.11571, saving model to model-dsbowl2018-1.h5
# 38/38 [==============================] - 38s 1s/step - loss: 0.1073 - mean_iou: 0.8458 - val_loss: 0.1157 - val_mean_iou: 0.8085
# Epoch 12/50
#  3/38 [=>............................] - ETA: 32s - loss: 0.0942 - mean_iou: 0.8311
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/vt/rk4nllrj0rl1sp0x1r1tvp_h0000gn/T/ipykernel_11055/3715075513.py in <module>
#       3 checkpointer = ModelCheckpoint('model-dsbowl2018-1.h5', verbose=1, save_best_only=True)
#       4 results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=16, epochs=50,
# ----> 5                     callbacks=[earlystopper, checkpointer])
#
# ~/anaconda3/envs/conda_new/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/envs/conda_new/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648                         ):
#    1649                             callbacks.on_train_batch_begin(step)
# -> 1650                             tmp_logs = self.train_function(iterator)
#    1651                             if data_handler.should_sync:
#    1652                                 context.async_wait()
#
# ~/anaconda3/envs/conda_new/lib/python3.7/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/envs/conda_new/lib/python3.7/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/envs/conda_new/lib/python3.7/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     910       # In this case we have created variables on the first call, so we run the
#     911       # defunned version which is guaranteed to never create variables.
# --> 912       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913     elif self._variable_creation_fn is not None:
#     914       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/conda_new/lib/python3.7/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#     134     return concrete_function._call_flat(
# --> 135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#     137   @property
#
# ~/anaconda3/envs/conda_new/lib/python3.7/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/anaconda3/envs/conda_new/lib/python3.7/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     381               inputs=args,
#     382               attrs=attrs,
# --> 383               ctx=ctx)
#     384         else:
#     385           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/conda_new/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51     ctx.ensure_initialized()
#      52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#      55     if name is not None:
#
# KeyboardInterrupt:

# %%
# Predict on train, val and test
model = load_model('model-dsbowl2018-1.h5', custom_objects={'mean_iou': mean_iou})
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 19/19 [==============================] - 7s 340ms/step
# 3/3 [==============================] - 1s 195ms/step
# 3/3 [==============================] - 1s 183ms/step

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()
